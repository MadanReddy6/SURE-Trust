# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)

# %%
plt.scatter(x,y, s=10)
plt.show()

# %%
x = np.random.rand(1000)
y = np.random.rand(1000)

# %%
plt.scatter(x,y, s=10)
plt.show()

# %%
data = pd.read_csv("economy.csv")
data.head(7)
# Out:
#    Year  GDP(Bil. US$PPP)  GDP per capita  GDP(Bil. US$nominal)  \
# 0  1980             372.3           532.6                 189.4
# 1  1981             432.0           603.8                 196.5
# 2  1982             474.6           648.2                 203.5
# 3  1983             529.1           706.1                 222.0
# 4  1984             569.2           742.3                 215.6
# 5  1985             618.0           788.0                 237.6
# 6  1986             660.6           823.7                 252.8
#
#    GDP per capita(US$ nominal)  GDP growth(Real)  Inflation rate(Percent)  \
# 0                        271.0               5.3                     11.3
# 1                        274.7               6.0                     12.7
# 2                        278.0               3.5                      7.7
# 3                        296.3               7.3                     12.6
# 4                        281.1               3.8                      6.5
# 5                        302.9               5.3                      6.3
# 6                        315.2               4.8                      8.9
#
#    Unemployment[182](Percent)  Government debt( of GDP)
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN

# %%
plt.plot(data["Year"],data["GDP per capita"])
plt.show()

# %%
plt.plot(data["Year"],data["Inflation rate(Percent)"])
plt.show()
