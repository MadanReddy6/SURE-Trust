# %%
import matplotlib.pyplot as plt

# %%
x = ["A","B","C","D","E","F","G","H"]
y = [34,23,29,45,67,43,89,23]

# %%
plt.bar(x,y,width=0.8, color=["red","green","black","yellow"])
plt.title("Random Data")
plt.xlabel("Yaay")
plt.ylabel("Whatever")

plt.ylim(0,100)
plt.show()
