# %%
import pandas as pd

# data = pd.read_csv("./data/Codeless_ports.csv",index_col="Sno",na_values=["Unknown","???"])
data = pd.read_csv("./data/Port_Data.csv",index_col="Unnamed: 0")
data.head()
# Out:
#   Country Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# 0   China  SHANGHAI   CNSHG             2420                       1376
# 1   China   NANTONG   CNNTG             1572                       1173
# 2   China       CJK   CNCJK             1529                        343
# 3   China   NANJING   CNNKG             1414                        667
# 4   China  JIANGYIN   CNJIA             1112                       1076
#
#    Arrivals(Last 24 Hours)  Expected Arrivals       Type      Area Local  \
# 0                     1626                644       Port  East China Sea
# 1                     1287                234       Port  East China Sea
# 2                      370                310  Anchorage  East China Sea
# 3                     1060                203       Port  East China Sea
# 4                     1070                166       Port  East China Sea
#
#      Area Global                                    Also known as
# ...

# %%
data[(data["Arrivals(Last 24 Hours)"] >= 700) | (data["Departures(Last 24 Hours)"] >= 700)]
# Out:
#       Country       Port Name UN Code  Vessels in Port  \
# 0       China        SHANGHAI   CNSHG             2420
# 1       China         NANTONG   CNNTG             1572
# 3       China         NANJING   CNNKG             1414
# 4       China        JIANGYIN   CNJIA             1112
# 5   Singapore       SINGAPORE   SGSIN             1109
# 7       China        ZHOUSHAN   CNZOS             1064
# 8       China        YANGZHOU   CNYZH              945
# 11  Hong Kong       HONG KONG   HKHKG              833
# 14      China       JINGJIANG   CNTSI              716
# 22  Singapore  SINGAPORE ANCH     NaN              516
# 42      China       ZHENJIANG   CNZHE              321
#
#     Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# 0                        1376                     1626                644
# 1                        1173                     1287                234
# 3                         667                     1060                203
# ...
