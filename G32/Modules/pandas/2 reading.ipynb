# %%
import pandas as pd

# %%
x = (2,3,4)

print(x)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
port_df = pd.read_csv("Port_Data.csv", index_col="Index", na_values=["['-']", "Unknown"])

# port_df["Port"] = port_df["Port Name"]
# port_df.drop("Port Name", axis = 1 ,inplace = True)

# port_df.to_csv("Port_Data_new.csv", index=False)
port_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 0 to 479
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    480 non-null    object
#  1   Port Name                  480 non-null    object
#  2   UN Code                    468 non-null    object
#  3   Vessels in Port            480 non-null    int64
#  4   Departures(Last 24 Hours)  480 non-null    int64
#  5   Arrivals(Last 24 Hours)    480 non-null    int64
#  6   Expected Arrivals          480 non-null    int64
#  7   Type                       480 non-null    object
#  8   Area Local                 480 non-null    object
#  9   Area Global                480 non-null    object
#  10  Also known as              262 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 45.0+ KB

# %%
port_df["Arrivals(Last 24 Hours)"].hist(bins=5, legend=True)
# Out:
# <Axes: >

# %%
china_df= port_df[port_df["Country"] == "India"]
china_df["Vessels in Port"].plot(kind="pie", labels= china_df["Port Name"])
# Out:
# <Axes: ylabel='Vessels in Port'>

# %%
for name, c_df in port_df.groupby("Country"):
    
    print(name, c_df)
# Out:
# Angola       Country Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 429    Angola    LUANDA   AOLAD               55                         13
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type   Area Local  \
# Index
# 429                         11                 36  Port  West Africa
#
#        Area Global Also known as
# Index
# 429    West Africa    ['ANGOLA']
# Argentina          Country      Port Name UN Code  Vessels in Port  \
# Index
# 170    Argentina   BUENOS AIRES   ARBUE              111
# 231    Argentina  MAR DEL PLATA   ARMDQ               88
# 315    Argentina       RECALADA       -               69
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 170                           37                       33                 10
# 231                            4                       12                 10
# 315                           18                       12                 37
#
#             Type                Area Local               Area Global  \
# Index
# 170         Port  East Coast South America  East Coast South America
# 231         Port  East Coast South America  East Coast South America
# 315    Anchorage  East Coast South America  East Coast South America
#
#                      Also known as
# Index
# 170    ['ZONA COMUN', ' DOCK SUD']
# 231          ['PTO MAR DEL PLATA']
# 315                            NaN
# Australia          Country         Port Name UN Code  Vessels in Port  \
# Index
# 129    Australia            SYDNEY   AUSYD              139
# 177    Australia            DARWIN   AUDRW              109
# 199    Australia          BRISBANE   AUBNE               96
# 223    Australia  CORAL SEA MARINA   AUALP               91
# 260    Australia     MANLY HARBOUR     NaN               82
# 279    Australia      PORT HEDLAND   AUPHE               76
# 280    Australia         GLADSTONE   AUGLT               76
# 335    Australia         FREMANTLE   AUFRE               66
# 346    Australia       HOPE ISLAND   AUHPL               65
# 369    Australia         MELBOURNE   AUMEL               62
# 396    Australia            CAIRNS   AUCNS               59
# 433    Australia        TOWNSVILLE   AUTSV               55
# 459    Australia     SOUTHPORT QLD   AUSHQ               53
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 129                          303                      306                 27
# 177                           22                       16                 25
# 199                           18                       24                 53
# 223                           44                       39                  0
# 260                            6                       22                  0
# 279                           59                       72                 95
# 280                           16                       14                 51
# 335                           58                       59                 12
# 346                           10                       11                  1
# 369                           31                       37                 32
# 396                           25                       29                  7
# 433                           57                       62                 13
# 459                           22                       20                  0
#
#          Type      Area Local      Area Global                  Also known as
# Index
# 129      Port       Coral Sea   East Australia                            NaN
# 177      Port       Timor Sea  North Australia                            NaN
# 199      Port       Coral Sea   East Australia                            NaN
# 223    Marina  East Australia   East Australia                            NaN
# 260    Marina       Coral Sea   East Australia             ['MANLY BRISBANE']
# 279      Port       Timor Sea   West Australia  ['PORT HEADLAND', ' HEDLAND']
# 280      Port       Coral Sea   East Australia                            NaN
# 335      Port  West Australia   West Australia                            NaN
# 346      Port       Coral Sea   East Australia                            NaN
# 369      Port      Tasman Sea   East Australia                            NaN
# 396      Port       Coral Sea   East Australia                            NaN
# 433      Port       Coral Sea   East Australia                            NaN
# 459      Port       Coral Sea   East Australia                  ['SOUTHPORT']
# Bahrain        Country Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 194    Bahrain    SITRAH   BHSIT              100                         44
# 237    Bahrain  MUHARRAQ   BHGBQ               87                          8
# 419    Bahrain    GALALI   BHQAL               57                          2
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type    Area Local  \
# Index
# 194                         41                  6  Port  Persian Gulf
# 237                          6                  1  Port  Persian Gulf
# 419                          1                  0  Port  Persian Gulf
#
#         Area Global    Also known as
# Index
# 194    Arabian Gulf        ['SITRA']
# 237    Arabian Gulf  ['AL MUHARRAQ']
# 419    Arabian Gulf       ['QALALI']
# Bangladesh           Country        Port Name UN Code  Vessels in Port  \
# Index
# 285    Bangladesh  CHITTAGONG ANCH       -               75
# 348    Bangladesh       CHITTAGONG   BDCGP               64
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 285                           22                       18                  0
# 348                           17                       13                105
#
#             Type  Area Local       Area Global   Also known as
# Index
# 285    Anchorage  Bengal Bay  East Coast India             NaN
# 348         Port  Bengal Bay  East Coast India  ['CHATTOGRAM']
# Belgium        Country     Port Name UN Code  Vessels in Port  \
# Index
# 15     Belgium       ANTWERP   BEANR              686
# 82     Belgium         GHENT   BEGNE              176
# 203    Belgium     ZEEBRUGGE   BEZEE               95
# 218    Belgium    NIEUWPOORT   BENIE               92
# 228    Belgium      OOSTENDE   BEOST               89
# 259    Belgium  ANTWERP ANCH       -               82
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 15                           211                      247                187
# 82                            86                       74                 42
# 203                           41                       45                 36
# 218                           36                       45                  2
# 228                           41                       56                 11
# 259                           52                       38                  0
#
#             Type       Area Local          Area Global  \
# Index
# 15          Port     Antwerp Area  UK Coast & Atlantic
# 82          Port     Antwerp Area  UK Coast & Atlantic
# 203         Port        North Sea  UK Coast & Atlantic
# 218         Port  English Channel  UK Coast & Atlantic
# 228         Port  English Channel  UK Coast & Atlantic
# 259    Anchorage        North Sea  UK Coast & Atlantic
#
#                                       Also known as
# Index
# 15     ['ANTWERPEN', ' BEANT', ' ANVERS', ' BEAAA']
# 82                               ['GENT', ' BEGGG']
# 203                                             NaN
# 218                                             NaN
# 228                          ['OSTEND', ' OSTENDE']
# 259                                             NaN
# Brazil       Country       Port Name UN Code  Vessels in Port  \
# Index
# 143    Brazil  RIO DE JANEIRO   BRRIO              127
# 150    Brazil          SANTOS   BRSSZ              119
# 254    Brazil     SANTOS ANCH     NaN               83
# 350    Brazil       PARANAGUA   BRPNG               64
# 457    Brazil  PARANAGUA ANCH     NaN               53
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 143                           38                       43                 39
# 150                           29                       28                147
# 254                           23                       22                  0
# 350                            9                       10                 41
# 457                            3                        8                  0
#
#             Type                Area Local               Area Global  \
# Index
# 143         Port  East Coast South America  East Coast South America
# 150         Port  East Coast South America  East Coast South America
# 254    Anchorage  East Coast South America  East Coast South America
# 350         Port  East Coast South America  East Coast South America
# 457    Anchorage  East Coast South America  East Coast South America
#
#                                            Also known as
# Index
# 143    ['RIODEJANEIRO', ' RIO DE JAN', ' RIO JANEIRO'...
# 150                                  ['BACIA DE SANTOS']
# 254                                                  NaN
# 350                                                  NaN
# 457                                                  NaN
# Bulgaria         Country Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 334    Bulgaria     VARNA   BGVAR               66                          6
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type Area Local  \
# Index
# 334                          7                 15  Port  Black Sea
#
#       Area Global                                      Also known as
# Index
# 334     Black Sea  ['BELOSLAV FERRY', ' WARNA', ' EZEROVO', ' LES...
# Canada       Country      Port Name UN Code  Vessels in Port  \
# Index
# 68     Canada      VANCOUVER   CAVAN              211
# 319    Canada        HALIFAX   CAHAL               68
# 367    Canada    FALSE CREEK       -               63
# 401    Canada        TORONTO   CATOR               59
# 426    Canada       VAN ISLE     NaN               56
# 438    Canada         QUEBEC   CAQUE               54
# 453    Canada  PRINCE RUPERT   CAPRR               53
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 68                            70                       88                 71
# 319                           18                       19                 39
# 367                           30                       36                  0
# 401                            9                        9                  1
# 426                           15                       24                  0
# 438                           17                       21                 20
# 453                           41                       46                 17
#
#          Type          Area Local        Area Global  \
# Index
# 68       Port   West Coast Canada  West Coast Canada
# 319      Port   East Coast Canada  East Coast Canada
# 367    Marina   West Coast Canada  West Coast Canada
# 401      Port        Lake Ontario        Great Lakes
# 426    Marina   West Coast Canada  West Coast Canada
# 438      Port  St. Lawrence River  East Coast Canada
# 453      Port   West Coast Canada  West Coast Canada
#
#                                Also known as
# Index
# 68     ['VANCOUVER BC', ' VANCOUVER CANADA']
# 319           ['DARTMOUTH', ' DARTMOUTH CA']
# 367                                      NaN
# 401                                      NaN
# 426                                      NaN
# 438                              ['SILLERY']
# 453                                      NaN
# Chile       Country     Port Name UN Code  Vessels in Port  \
# Index
# 303     Chile  PUERTO MONTT   CLPMC               71
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 303                           21                       22                 15
#
#        Type          Area Local         Area Global  Also known as
# Index
# 303    Port  West South America  West South America  ['PTO MONTT']
# China       Country   Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 0       China    SHANGHAI   CNSHG             2420                       1376
# 1       China     NANTONG   CNNTG             1572                       1173
# 2       China         CJK   CNCJK             1529                        343
# 3       China     NANJING   CNNKG             1414                        667
# 4       China    JIANGYIN   CNJIA             1112                       1076
# ...       ...         ...     ...              ...                        ...
# 393     China      LUSHUN   CNLSH               59                         85
# 424     China  LIAN JIANG   CNLNJ               56                         37
# 427     China     BINZHOU   CNBIN               55                         44
# 474     China      FUZHOU   CNFOC               51                         18
# 476     China     PENGLAI   CNPLI               51                         63
#
#        Arrivals(Last 24 Hours)  Expected Arrivals       Type      Area Local  \
# Index
# 0                         1626                644       Port  East China Sea
# 1                         1287                234       Port  East China Sea
# 2                          370                310  Anchorage  East China Sea
# 3                         1060                203       Port  East China Sea
# 4                         1070                166       Port  East China Sea
# ...                        ...                ...        ...             ...
# 393                         94                 16       Port       Bohai Sea
# 424                         25                  3       Port  East China Sea
# 427                         42                 38       Port       Bohai Sea
# 474                         23                 89       Port  East China Sea
# 476                         61                 22       Port       Bohai Sea
#
#          Area Global                                    Also known as
# Index
# 0      Central China   ['SHANG HAI', ' YANGSHAN', ' CNSHA', ' CNSGH']
# 1      Central China                                     ['NAN TONG']
# 2      Central China  ['CHANGJIANGKOU', ' CHANGJIANG KOU', ' CJK CN']
# 3      Central China              ['NAN JING', ' NAN JIN', ' NANJIN']
# 4      Central China                 ['-', ' JANG JIN', ' JIANG YIN']
# ...              ...                                              ...
# 393      North China                           ['LVSHUN', ' LU SHUN']
# 424      South China                        ['LIANJIANG', ' HUANGQI']
# 427      North China                ['BIN ZHOU', ' TAOER RIVER PORT']
# 474      South China                            ['FU ZHOU', ' MAWEI']
# 476      North China                           ['PENG LAI', ' CNPLA']
#
# [122 rows x 11 columns]
# Colombia         Country  Port Name UN Code  Vessels in Port  \
# Index
# 212    Colombia  CARTAGENA   COCTG               92
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 212                          126                      136                 33
#
#        Type                 Area Local                Area Global  \
# Index
# 212    Port  North Coast South America  North Coast South America
#
#                             Also known as
# Index
# 212    ['MAMONAL', ' CARTAGENA COLOMBIA']
# Denmark        Country   Port Name UN Code  Vessels in Port  \
# Index
# 132    Denmark  COPENHAGEN   DKCPH              137
# 332    Denmark      SKAGEN   DKSKA               66
# 374    Denmark   HIRTSHALS   DKHIR               62
# 398    Denmark   HANSTHOLM   DKHAN               59
# 415    Denmark     ESBJERG   DKEBJ               57
# 455    Denmark   GILLELEJE   DKGLE               53
# 465    Denmark     AALBORG   DKAAL               52
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 132                           43                       53                  7
# 332                           28                       44                 37
# 374                           24                       46                 10
# 398                            9                       31                  6
# 415                           60                       69                 15
# 455                           19                       26                  4
# 465                            9                       22                  7
#
#        Type Area Local          Area Global                 Also known as
# Index
# 132    Port   Kattegat           Baltic Sea  ['KOBENHAVN', ' KOEBENHAVN']
# 332    Port   Kattegat           Baltic Sea                      ['SKAW']
# 374    Port   Kattegat  UK Coast & Atlantic                           NaN
# 398    Port  North Sea  UK Coast & Atlantic                           NaN
# 415    Port  North Sea  UK Coast & Atlantic                           NaN
# 455    Port   Kattegat           Baltic Sea                           NaN
# 465    Port   Kattegat  UK Coast & Atlantic               ['NORRESUNDBY']
# Ecuador        Country  Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 394    Ecuador  GUAYAQUIL   ECGYE               59                         10
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type          Area Local  \
# Index
# 394                         11                 13  Port  West South America
#
#               Area Global Also known as
# Index
# 394    West South America           NaN
# Egypt       Country   Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 266     Egypt  SUEZ CANAL   EGSUZ               79                         30
#
#        Arrivals(Last 24 Hours)  Expected Arrivals   Type          Area Local  \
# Index
# 266                         75                409  Canal  East Mediterranean
#
#               Area Global                           Also known as
# Index
# 266    East Mediterranean  ['SUEZ', ' EGSZC', ' EGSUC', ' EGSCN']
# Finland        Country Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 265    Finland  HELSINKI   FIHEL               80                        101
# 425    Finland     TURKU   FITKU               56                         10
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type    Area Local  \
# Index
# 265                        123                 13  Port  Finland Gulf
# 425                         14                  2  Port  Bothnia Gulf
#
#       Area Global Also known as
# Index
# 265    Baltic Sea           NaN
# 425    Baltic Sea       ['ABO']
# France       Country          Port Name UN Code  Vessels in Port  \
# Index
# 138    France  LA ROCHELLE VIEUX     NaN              129
# 154    France            ANTIBES   FRANT              119
# 179    France           LE HAVRE   FRLEH              107
# 201    France              BREST   FRBES               96
# 230    France          MARSEILLE   FRMRS               88
# 269    France       SAINT TROPEZ   FRSTP               79
# 278    France              PARIS   FRPAR               77
# 307    France            LORIENT   FRLRT               71
# 351    France        FOS SUR MER   FRFOS               64
# 372    France              ROUEN   FRURO               62
# 410    France   PORT DU CROUESTY   FRRZN               58
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 138                           32                       77                  0
# 154                           18                       21                  6
# 179                           69                       79                 39
# 201                           38                       66                  6
# 230                           72                       91                 11
# 269                           54                       86                  6
# 278                           16                       16                 16
# 307                           38                       59                  8
# 351                           27                       35                 23
# 372                           15                       28                 17
# 410                           18                       49                  0
#
#          Type          Area Local          Area Global  \
# Index
# 138      Port          Biscay Bay  UK Coast & Atlantic
# 154      Port        Ligurean Sea   West Mediterranean
# 179      Port     English Channel  UK Coast & Atlantic
# 201      Port          Biscay Bay  UK Coast & Atlantic
# 230      Port  West Mediterranean   West Mediterranean
# 269    Marina        Ligurean Sea   West Mediterranean
# 278      Port      Inland, Europe       Inland, Europe
# 307      Port          Biscay Bay  UK Coast & Atlantic
# 351      Port  West Mediterranean   West Mediterranean
# 372      Port      Inland, Europe       Inland, Europe
# 410      Port          Biscay Bay  UK Coast & Atlantic
#
#                                            Also known as
# Index
# 138                                                  NaN
# 154                                                  NaN
# 179                                          ['LEHAVRE']
# 201                                                  NaN
# 230                                                  NaN
# 269                                        ['ST TROPEZ']
# 278                                                  NaN
# 307                                                  NaN
# 351    ['FRFZS', ' FOS FRANCE', ' FOS SUR MER FRANCE'...
# 372                                                  NaN
# 410                                            ['ARZON']
# Germany        Country          Port Name UN Code  Vessels in Port  \
# Index
# 32     Germany            HAMBURG   DEHAM              389
# 118    Germany            ROSTOCK   DERSK              145
# 123    Germany        BREMERHAVEN   DEBRV              142
# 156    Germany               KIEL   DEKEL              118
# 183    Germany           CUXHAVEN   DECUX              105
# 188    Germany             BERLIN   DEBER              103
# 196    Germany           DUISBURG   DEDUI               98
# 257    Germany      HEILIGENHAFEN   DEHHF               82
# 277    Germany             BREMEN   DEBRE               77
# 330    Germany           NEUSTADT   DENDT               67
# 345    Germany  NORD-OSTSEE-KANAL   DECKL               65
# 387    Germany      WILHELMSHAVEN   DEWVN               60
# 389    Germany         TRAVEMUNDE   DETRV               60
# 395    Germany             LUBECK   DELBC               59
# 440    Germany              EMDEN   DEEME               54
# 449    Germany              LABOE   DELAB               54
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 32                            69                       83                 72
# 118                           66                       81                 17
# 123                           80                       80                 35
# 156                           60                       89                 15
# 183                           45                       55                 15
# 188                           18                       20                 13
# 196                           63                       78                 17
# 257                           26                       32                  2
# 277                           22                       24                 17
# 330                           20                       27                  1
# 345                           84                       82                  5
# 387                           15                       22                 17
# 389                           54                       54                  6
# 395                           24                       39                  9
# 440                           29                       38                 12
# 449                           34                       50                  0
#
#          Type      Area Local          Area Global  \
# Index
# 32       Port      Elbe River  UK Coast & Atlantic
# 118      Port      Baltic Sea           Baltic Sea
# 123      Port      Elbe River  UK Coast & Atlantic
# 156      Port      Kiel Canal           Baltic Sea
# 183      Port      Elbe River  UK Coast & Atlantic
# 188      Port  Inland, Europe       Inland, Europe
# 196      Port  Inland, Europe       Inland, Europe
# 257      Port      Baltic Sea           Baltic Sea
# 277      Port       North Sea       Inland, Europe
# 330      Port      Baltic Sea           Baltic Sea
# 345     Canal      Kiel Canal  UK Coast & Atlantic
# 387      Port       North Sea  UK Coast & Atlantic
# 389      Port      Baltic Sea           Baltic Sea
# 395      Port      Baltic Sea           Baltic Sea
# 440      Port       North Sea  UK Coast & Atlantic
# 449    Marina      Kiel Canal           Baltic Sea
#
#                                    Also known as
# Index
# 32                                     ['DEHBU']
# 118    ['ROSTOK', ' WARNEMUNDE', ' WARNEMUENDE']
# 123                              ['BREMERHAFEN']
# 156                                          NaN
# 183                         ['CUXHAFEN', ' CUX']
# 188                                          NaN
# 196                                          NaN
# 257                                          NaN
# 277                                          NaN
# 330                                          NaN
# 345                               ['KIEL CANAL']
# 387                               ['JADE WESER']
# 389                              ['TRAVEMUENDE']
# 395                                  ['LUEBECK']
# 440                                          NaN
# 449                                          NaN
# Gibraltar          Country  Port Name UN Code  Vessels in Port  \
# Index
# 224    Gibraltar  GIBRALTAR   GIGIB               90
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 224                           79                       89                100
#
#        Type Area Local         Area Global Also known as
# Index
# 224    Port  Gibraltar  West Mediterranean           NaN
# Greece       Country     Port Name UN Code  Vessels in Port  \
# Index
# 168    Greece       FLISVOS       -              113
# 272    Greece       PIRAEUS   GRPIR               78
# 309    Greece           ZEA   GRMAZ               71
# 378    Greece        GOUVIA       -               62
# 468    Greece  AGIOS KOSMAS       -               52
# 469    Greece        ALIMOS   GRAIO               52
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 168                           13                       35                  3
# 272                          117                      122                 66
# 309                            8                       14                  2
# 378                           18                       22                  0
# 468                            4                       17                  2
# 469                           24                       24                  2
#
#          Type    Area Local         Area Global  \
# Index
# 168    Marina  Piraeus Area  East Mediterranean
# 272      Port  Piraeus Area  East Mediterranean
# 309    Marina  Piraeus Area  East Mediterranean
# 378    Marina    Ionian Sea  East Mediterranean
# 468    Marina  Piraeus Area  East Mediterranean
# 469    Marina  Piraeus Area  East Mediterranean
#
#                                          Also known as
# Index
# 168                                                NaN
# 272    ['PIRAEVS', ' PIREAS', ' KERATSINI', ' ATHENS']
# 309                     ['ZEA MARINA', ' MARINA ZEAS']
# 378                                        ['TZAVROS']
# 468                        ['AG.KOSMAS', ' AG KOSMAS']
# 469                                         ['ALIMOU']
# Guernsey         Country Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 323    Guernsey  GUERNSEY   GGGCI               68                         24
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type       Area Local  \
# Index
# 323                         31                  1  Port  English Channel
#
#                Area Global                            Also known as
# Index
# 323    UK Coast & Atlantic  ['-', ' SAINT PETER', ' ST PETER PORT']
# Guinea       Country    Port Name UN Code  Vessels in Port  \
# Index
# 400    Guinea  KAMSAR ANCH       -               59
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 400                           32                       29                  2
#
#             Type   Area Local  Area Global Also known as
# Index
# 400    Anchorage  West Africa  West Africa           NaN
# Hong Kong          Country       Port Name UN Code  Vessels in Port  \
# Index
# 11     Hong Kong       HONG KONG   HKHKG              833
# 328    Hong Kong  HONG KONG ANCH       -               67
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 11                           766                      753                202
# 328                          117                      112                  3
#
#             Type   Area Local  Area Global  \
# Index
# 11          Port  South China  South China
# 328    Anchorage  South China  South China
#
#                                            Also known as
# Index
# 11     ['HONGKONG', ' CN HKG', ' XIANGGANG', ' XIANG ...
# 328                                                  NaN
# Hungary        Country Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 206    Hungary  BUDAPEST   HUBUD               93                         17
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type      Area Local  \
# Index
# 206                         21                 38  Port  Inland, Europe
#
#           Area Global Also known as
# Index
# 206    Inland, Europe           NaN
# India       Country    Port Name UN Code  Vessels in Port  \
# Index
# 114     India  MUMBAI ANCH       -              148
# 233     India       MUMBAI   INBOM               87
# 282     India        SIKKA   INSIK               75
# 299     India       HAZIRA   INHZR               72
# 370     India       MUNDRA   INMUN               62
# 379     India        KOCHI   INCOK               61
# 478     India     KAKINADA   INKAK               51
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 114                           88                       82                  3
# 233                           75                       74                 64
# 282                            6                        4                 24
# 299                           67                       71                 27
# 370                           38                       40                 31
# 379                           38                       43                 26
# 478                            8                       10                 21
#
#             Type        Area Local       Area Global          Also known as
# Index
# 114    Anchorage  West Coast India  West Coast India                    NaN
# 233         Port  West Coast India  West Coast India             ['BOMBAY']
# 282         Port  West Coast India  West Coast India                    NaN
# 299         Port  West Coast India  West Coast India  ['SURAT', ' GANDHAR']
# 370         Port  West Coast India  West Coast India                    NaN
# 379         Port  West Coast India  West Coast India   ['COCHIN', ' INKOC']
# 478         Port        Bengal Bay  East Coast India                    NaN
# Indonesia          Country         Port Name UN Code  Vessels in Port  \
# Index
# 76     Indonesia        BATU AMPAR   IDBUR              187
# 77     Indonesia           JAKARTA   IDJKT              186
# 98     Indonesia  MUARA BERAU ANCH   IDMUB              162
# 133    Indonesia      TABONEO ANCH   IDTAB              133
# 161    Indonesia       BANJARMASIN   IDBDJ              116
# 184    Indonesia      JAKARTA ANCH       -              105
# 267    Indonesia         PALEMBANG   IDPLM               79
# 287    Indonesia          SURABAYA   IDSUB               74
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 76                           128                      124                 40
# 77                            95                      116                 81
# 98                            59                       61                  6
# 133                           72                       69                 33
# 161                           35                       67                 25
# 184                           52                       71                  0
# 267                           31                       26                 30
# 287                           54                       58                 53
#
#             Type       Area Local Area Global  \
# Index
# 76          Port   Singapore Area   Indonesia
# 77          Port         Java Sea   Indonesia
# 98     Anchorage  Makassar Strait   Indonesia
# 133    Anchorage         Java Sea   Indonesia
# 161         Port         Java Sea   Indonesia
# 184    Anchorage         Java Sea   Indonesia
# 267         Port         Java Sea   Indonesia
# 287         Port         Java Sea   Indonesia
#
#                                            Also known as
# Index
# 76                  ['BATAM', ' BATUAMPAR', ' SEKUPANG']
# 77     ['PRIOK', ' TANJUNG PRIOK', ' ID TPP', ' TG PR...
# 98                                                   NaN
# 133                                          ['TABONEO']
# 161                                           ['BANJAR']
# 184                                                  NaN
# 267                                            ['PLAJU']
# 287                                    ['TANJUNG PERAK']
# Iran       Country          Port Name UN Code  Vessels in Port  \
# Index
# 376      Iran  BANDAR ABBAS ANCH       -               62
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 376                           26                       20                  1
#
#             Type    Area Local   Area Global Also known as
# Index
# 376    Anchorage  Persian Gulf  Arabian Gulf           NaN
# Israel       Country Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 371    Israel     HAIFA   ILHFA               62                         26
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type          Area Local  \
# Index
# 371                         20                 20  Port  East Mediterranean
#
#               Area Global Also known as
# Index
# 371    East Mediterranean           NaN
# Italy       Country  Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 95      Italy     GENOVA   ITGOA              165                         55
# 145     Italy  LA SPEZIA   ITSPE              124                         22
# 314     Italy    LIVORNO   ITLIV               69                         28
# 383     Italy     VENICE   ITVCE               60                         30
# 407     Italy     NAPOLI   ITNAP               58                         31
# 445     Italy    SANREMO   ITSRE               54                          9
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type      Area Local  \
# Index
# 95                          44                 42  Port    Ligurean Sea
# 145                         30                 16  Port    Ligurean Sea
# 314                         28                 37  Port    Ligurean Sea
# 383                         28                 28  Port    Adriatic Sea
# 407                         30                 16  Port  Tyrrhenian Sea
# 445                          7                  5  Port    Ligurean Sea
#
#               Area Global                                      Also known as
# Index
# 95     West Mediterranean                                          ['GENOA']
# 145    West Mediterranean                                       ['LASPEZIA']
# 314    West Mediterranean                                                NaN
# 383          Adriatic Sea  ['VENEZIA', ' PORTO MARGHERA', ' ITPMA', ' MAR...
# 407    West Mediterranean                                         ['NAPLES']
# 445    West Mediterranean                                       ['SAN REMO']
# Ivory Coast            Country Port Name UN Code  Vessels in Port  \
# Index
# 431    Ivory Coast   ABIDJAN   CIABJ               55
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 431                            6                        5                 27
#
#        Type      Area Local  Area Global Also known as
# Index
# 431    Port  Gulf of Guinea  West Africa    ['ABIJAN']
# Japan       Country  Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 139     Japan   YOKOHAMA   JPYOK              128                        204
# 146     Japan     NAGOYA   JPNGO              122                        115
# 243     Japan      TOKYO   JPTYO               85                         73
# 247     Japan       KOBE   JPUKB               84                        128
# 286     Japan      OSAKA   JPOSA               74                         93
# 413     Japan  MIZUSHIMA   JPMIZ               57                         87
# 417     Japan  TOKYO BAY       -               57                        200
# 451     Japan      SAKAI   JPSAK               53                        100
# 462     Japan    KUSHIRO   JPKUH               52                         73
# 479     Japan       NAHA   JPNAH               51                         33
#
#        Arrivals(Last 24 Hours)  Expected Arrivals       Type      Area Local  \
# Index
# 139                        234                113       Port     Japan Coast
# 146                        114                105       Port     Japan Coast
# 243                         88                 89       Port     Japan Coast
# 247                        119                 59       Port     Japan Coast
# 286                        109                 63       Port     Japan Coast
# 413                         80                 93       Port     Japan Coast
# 417                        181                  3  Anchorage     Japan Coast
# 451                         97                 54       Port     Japan Coast
# 462                         57                 20       Port     Japan Coast
# 479                         42                 15       Port  East China Sea
#
#        Area Global                Also known as
# Index
# 139    Japan Coast       ['NEGISHI', ' YKHAMA']
# 146    Japan Coast                          NaN
# 243    Japan Coast                    ['JAPAN']
# 247    Japan Coast                          NaN
# 286    Japan Coast                    ['SAKAI']
# 413    Japan Coast                          NaN
# 417    Japan Coast                          NaN
# 451    Japan Coast  ['SAKAISENBOKU', ' JP SBK']
# 462    Japan Coast                  ['HIGASHI']
# 479    Japan Coast                          NaN
# Jersey       Country  Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 326    Jersey  ST HELIER   JESTH               67                         28
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type       Area Local  \
# Index
# 326                         28                  7  Port  English Channel
#
#                Area Global Also known as
# Index
# 326    UK Coast & Atlantic    ['JERSEY']
# Korea       Country       Port Name UN Code  Vessels in Port  \
# Index
# 27      Korea           BUSAN   KRPUS              438
# 31      Korea         INCHEON   KRINC              391
# 45      Korea           ULSAN   KRUSN              303
# 47      Korea           YEOSU   KRYOS              284
# 81      Korea           MOKPO   KRMOK              177
# 174     Korea      PYEONGTAEK   KRPTK              109
# 226     Korea       GWANGYANG   KRKAN               89
# 235     Korea          POHANG   KRKPO               87
# 358     Korea          DAESAN   KRTSN               63
# 406     Korea  BUSAN NEW PORT   KRBNP               58
# 423     Korea         GOHYEON   KRKHN               56
# 444     Korea      YEOSU ANCH       -               54
# 450     Korea       TONGYEONG   KRTYG               53
# 454     Korea      SAMCHEONPO   KRSCP               53
# 475     Korea           ONSAN   KRONS               51
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 27                           362                      351                252
# ...
# 23          Port      US East Coast      US East Coast
# 29          Port      US West Coast      US West Coast
# 35          Port     Gulf of Mexico     Gulf of Mexico
# 36          Port      US West Coast      US West Coast
# 38          Port       Hudson River      US East Coast
# 39          Port     Gulf of Mexico     Gulf of Mexico
# 72          Port      US East Coast      US East Coast
# 80          Port  West Coast Canada  West Coast Canada
# 83          Port      US East Coast      US East Coast
# 99          Port     Gulf of Mexico     Gulf of Mexico
# 115         Port      US West Coast      US West Coast
# 121         Port      US East Coast      US East Coast
# 130         Port      US West Coast      US West Coast
# 131         Port      US East Coast      US East Coast
# 152         Port      US West Coast      US West Coast
# 182         Port     Gulf of Mexico     Gulf of Mexico
# 186         Port      US West Coast      US West Coast
# 208         Port      US East Coast      US East Coast
# 214         Port      US West Coast      US West Coast
# 221         Port      US West Coast      US West Coast
# 245         Port      US East Coast      US East Coast
# 246         Port      US West Coast      US West Coast
# 249         Port      US East Coast      US East Coast
# 252         Port     Gulf of Mexico     Gulf of Mexico
# 270         Port  West Coast Canada  West Coast Canada
# 305         Port             Hawaii      North Pacific
# 306         Port      US West Coast      US West Coast
# 312         Port      US East Coast      US East Coast
# 317    Anchorage     Gulf of Mexico     Gulf of Mexico
# 333         Port      US West Coast      US West Coast
# 339         Port      US West Coast      US West Coast
# 347       Marina      US West Coast      US West Coast
# 362         Port     Gulf of Mexico     Gulf of Mexico
# 363         Port      Lake Michigan        Great Lakes
# 380         Port     Gulf of Mexico     Gulf of Mexico
# 381         Port      US East Coast      US East Coast
# 392         Port     Gulf of Mexico     Gulf of Mexico
# 404       Marina      US West Coast      US West Coast
# 412       Marina     Gulf of Mexico     Gulf of Mexico
# 447       Marina      US West Coast      US West Coast
# 452         Port     Gulf of Mexico     Gulf of Mexico
# 463         Port     Gulf of Alaska             Alaska
# 467         Port      US East Coast      US East Coast
# 470         Port      US East Coast      US East Coast
# 477         Port      US East Coast      US East Coast
#
#                                            Also known as
# Index
# 23     ['FT LAUDERDALE', ' LAUDERDALE', ' FTLAUDERDALE']
# 29                                                   NaN
# 35                                           ['BAYTOWN']
# 36     ['SANDIEGO', ' MARINA CORTEZ', ' HARBOR ISLAND...
# 38        ['BAYONNE USA', ' USNWK', ' NEWARK', ' USEWR']
# 39     ['NEWORLEANS', ' NOLA', ' NEW ORLEAN', ' GRAND...
# 72                                                   NaN
# 80                                                   NaN
# 83                                                   NaN
# 99                         ['PORT FOURCHON', ' FOUCHON']
# 115                                                  NaN
# 121                                       ['NEWPORT RI']
# 130                                                  NaN
# 131                                                  NaN
# 152                         ['LOSANGELES', ' SAN PEDRO']
# 182                                                  NaN
# 186                                    ['SHILSHOLE BAY']
# 208                                                  NaN
# 214                             ['PORTLAND', ' LINNTON']
# 221                                                  NaN
# 245                                                  NaN
# 246                                        ['LONGBEACH']
# 249                                                  NaN
# 252                                                  NaN
# 270                                                  NaN
# 305                                                  NaN
# 306                                                  NaN
# 312                                         ['PORTLAND']
# 317                                                  NaN
# 333                                                  NaN
# 339                                                  NaN
# 347               ['PENINSULA BASIN', ' SEATTLE AT GIG']
# 362                                                  NaN
# 363                                                  NaN
# 380                                                  NaN
# 381                                                  NaN
# 392                      ['C CHRISTI', ' CORPUS CRISTI']
# 404    ['-', ' SAUSALITO YACHT ', ' ISSAQUAH DOCK', '...
# 412      ['SOUTH TEXAS SERVICES', ' WATERGATE YACHTING']
# 447    ['LONG BEACH YACHT', ' ALAMITOS', ' NAPLES ISL...
# 452                                                  NaN
# 463                                          ['AFOGNAK']
# 467    ['NIEMIEC MARINE', ' HOMERS WHARF', ' WHALING ...
# 470                                                  NaN
# 477                                                  NaN
# Ukraine        Country Port Name UN Code  Vessels in Port  Departures(Last 24 Hours)  \
# Index
# 236    Ukraine    IZMAIL   UAIZM               87                         18
# 304    Ukraine      RENI   UARNI               71                          3
#
#        Arrivals(Last 24 Hours)  Expected Arrivals  Type      Area Local  \
# Index
# 236                         17                 19  Port       Black Sea
# 304                          5                 14  Port  Inland, Europe
#
#           Area Global Also known as
# Index
# 236         Black Sea           NaN
# 304    Inland, Europe           NaN
# United Arab Emirates                     Country         Port Name UN Code  Vessels in Port  \
# Index
# 59     United Arab Emirates             DUBAI   AEDXB              247
# 125    United Arab Emirates     FUJAIRAH ANCH       -              140
# 164    United Arab Emirates          FUJAIRAH   AEFJR              113
# 171    United Arab Emirates          MUSAFFAH   AEAMF              111
# 258    United Arab Emirates      SHARJAH ANCH       -               82
# 292    United Arab Emirates           SHARJAH   AESHJ               73
# 311    United Arab Emirates             ZAKUM       -               70
# 313    United Arab Emirates         JEBEL ALI   AEJEA               69
# 354    United Arab Emirates           HAMRIYA   AEHAM               64
# 356    United Arab Emirates  KHOR FAKKAN ANCH       -               64
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 59                            35                       56                 25
# 125                          166                      157                  4
# 164                          127                      129                200
# 171                           30                       20                 10
# 258                           59                       52                  2
# 292                           41                       52                 17
# 311                           34                       35                 11
# 313                           64                       60                 75
# 354                            8                        6                 14
# 356                           62                       55                  2
#
#             Type    Area Local   Area Global  \
# Index
# 59          Port    Dubai Area  Arabian Gulf
# 125    Anchorage     Oman Gulf  Arabian Gulf
# 164         Port     Oman Gulf  Arabian Gulf
# 171         Port  Persian Gulf  Arabian Gulf
# 258    Anchorage    Dubai Area  Arabian Gulf
# 292         Port  Persian Gulf  Arabian Gulf
# 311         Port  Persian Gulf  Arabian Gulf
# 313         Port  Persian Gulf  Arabian Gulf
# 354         Port  Persian Gulf  Arabian Gulf
# 356    Anchorage     Oman Gulf  Arabian Gulf
#
#                                            Also known as
# Index
# 59                ['PORTRASHID', ' PORT RASHID', ' DMC']
# 125                                                  NaN
# 164                          ['AL FUJAIRAH', ' FUJAIRA']
# 171    ['MUSAFAH', ' MUSSAFAH', ' MUSSAFFAH', ' ESNAAD']
# 258                                                  NaN
# 292    ['MINA KHALID', ' PORT KHALID', ' KHALID', ' A...
# 311                 ['ZUKUM', ' ZAKUM FIELD', ' ZAKKUM']
# 313             ['JEBELALI', ' JEBAL ALI', ' JABAL ALI']
# 354                                       ['AL HAMRIYA']
# 356                                                  NaN
# United Kingdom               Country     Port Name UN Code  Vessels in Port  \
# Index
# 93     United Kingdom      PLYMOUTH   GBPLY              168
# 134    United Kingdom       GOSPORT   GBGOS              133
# 160    United Kingdom   SOUTHAMPTON   GBSOU              116
# 197    United Kingdom     LYMINGTON   GBLYM               98
# 205    United Kingdom       MERCURY       -               94
# 215    United Kingdom        LONDON   GBLON               92
# 240    United Kingdom      FALMOUTH   GBFAL               86
# 253    United Kingdom  HAMBLE POINT       -               83
# 325    United Kingdom         COWES   GBCOW               68
# 343    United Kingdom       GRIMSBY   GBGSY               65
# 399    United Kingdom     LOWESTOFT   GBLOW               59
# 418    United Kingdom         POOLE   GBPOO               57
# 420    United Kingdom        SOLENT       -               57
# 435    United Kingdom   PORTLAND UK   GBPTL               55
# 458    United Kingdom   PORT HAMBLE       -               53
# 464    United Kingdom     LIVERPOOL   GBLIV               52
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 93                            40                       72                  9
# 134                           82                      107                  0
# 160                          126                      119                 30
# 197                           72                       76                  0
# 205                           24                       62                  0
# 215                          112                      110                 11
# 240                           39                       54                  5
# 253                           51                       78                  0
# 325                          152                      106                  0
# 343                           36                       61                  6
# 399                           25                       34                  3
# 418                           29                       46                  1
# 420                           12                       32                  0
# 435                           22                       28                  1
# 458                           22                       39                  0
# 464                           31                       45                 12
#
#          Type       Area Local          Area Global  \
# Index
# 93       Port  English Channel  UK Coast & Atlantic
# 134      Port  English Channel  UK Coast & Atlantic
# 160      Port  English Channel  UK Coast & Atlantic
# 197      Port  English Channel  UK Coast & Atlantic
# 205    Marina  English Channel  UK Coast & Atlantic
# 215      Port        North Sea  UK Coast & Atlantic
# 240      Port       Celtic Sea  UK Coast & Atlantic
# 253    Marina  English Channel  UK Coast & Atlantic
# 325      Port  English Channel  UK Coast & Atlantic
# 343      Port        North Sea  UK Coast & Atlantic
# 399      Port        North Sea  UK Coast & Atlantic
# 418      Port  English Channel  UK Coast & Atlantic
# 420      Port  English Channel  UK Coast & Atlantic
# 435      Port  English Channel  UK Coast & Atlantic
# 458    Marina  English Channel  UK Coast & Atlantic
# 464      Port        Irish Sea  UK Coast & Atlantic
#
#                      Also known as
# Index
# 93                             NaN
# 134                            NaN
# 160                  ['MARCHWOOD']
# 197                            NaN
# 205    ['SOUTHAMPTON', ' HAMPSHI']
# 215                            NaN
# 240         ['NORTH END SHIPYARD']
# 253    ['SOUTHAMPTON', ' HAMPSHI']
# 325                            NaN
# 343                            NaN
# 399       ['BOULEVARD LEISURE CE']
# 418                            NaN
# 420                            NaN
# 435                   ['PORTLAND']
# 458    ['SOUTHAMPTON', ' HAMPSHI']
# 464                            NaN
# Uruguay        Country   Port Name UN Code  Vessels in Port  \
# Index
# 227    Uruguay  MONTEVIDEO   UYMVD               89
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 227                           10                       11                 22
#
#        Type                Area Local               Area Global  \
# Index
# 227    Port  East Coast South America  East Coast South America
#
#                   Also known as
# Index
# 227    ['PUERTO DE MONTEVIDEO']
# Vietnam        Country     Port Name UN Code  Vessels in Port  \
# Index
# 67     Vietnam     HAI PHONG   VNHPH              215
# 96     Vietnam   HO CHI MINH   VNSGN              163
# 175    Vietnam      VUNG TAU   VNVUT              109
# 336    Vietnam      NGHI SON   VNNGH               66
# 409    Vietnam  HON GAI ANCH       -               58
#
#        Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# Index
# 67                            78                      103                 70
# 96                            42                       63                 60
# 175                           98                      125                 63
# 336                           17                       20                 11
# 409                           22                       20                  3
#
#             Type       Area Local      Area Global  \
# Index
# 67          Port  South-East Asia  South-East Asia
# 96          Port  South-East Asia  South-East Asia
# 175         Port  South-East Asia  South-East Asia
# 336         Port  South-East Asia  South-East Asia
# 409    Anchorage  South-East Asia  South-East Asia
#
#                                 Also known as
# Index
# 67                               ['HAIPHONG']
# 96      ['SAIGON', ' CAT LAI', ' HIEP PHUOC']
# 175                               ['VUNGTAU']
# 336    ['THANH HOA', ' VN THO', ' THANH HAO']
# 409                                       NaN

# %%
# hv_port_df = port_df[port_df["Vessels in Port"] > port_df["Vessels in Port"].mean()]

# get port names where departures are greater than arrivals
port_df[(port_df["Departures(Last 24 Hours)"] < port_df["Arrivals(Last 24 Hours)"]) | (port_df["Vessels in Port"] > 100)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 0 to 479
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    368 non-null    object
#  1   Port Name                  368 non-null    object
#  2   UN Code                    358 non-null    object
#  3   Vessels in Port            368 non-null    int64
#  4   Departures(Last 24 Hours)  368 non-null    int64
#  5   Arrivals(Last 24 Hours)    368 non-null    int64
#  6   Expected Arrivals          368 non-null    int64
#  7   Type                       368 non-null    object
#  8   Area Local                 368 non-null    object
#  9   Area Global                368 non-null    object
#  10  Also known as              212 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 34.5+ KB

# %%
port_df[(port_df["Departures(Last 24 Hours)"] < port_df["Arrivals(Last 24 Hours)"]) & (port_df["Vessels in Port"] > 100)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 0 to 192
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    138 non-null    object
#  1   Port Name                  138 non-null    object
#  2   UN Code                    133 non-null    object
#  3   Vessels in Port            138 non-null    int64
#  4   Departures(Last 24 Hours)  138 non-null    int64
#  5   Arrivals(Last 24 Hours)    138 non-null    int64
#  6   Expected Arrivals          138 non-null    int64
#  7   Type                       138 non-null    object
#  8   Area Local                 138 non-null    object
#  9   Area Global                138 non-null    object
#  10  Also known as              90 non-null     object
# dtypes: int64(4), object(7)
# memory usage: 12.9+ KB

# %%
# port_df[port_df["Also known as"].notnull()]
port_df.dropna(subset=["UN Code", "Also known as"], inplace = True)

# %%
port_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 0 to 476
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    257 non-null    object
#  1   Port Name                  257 non-null    object
#  2   UN Code                    257 non-null    object
#  3   Vessels in Port            257 non-null    int64
#  4   Departures(Last 24 Hours)  257 non-null    int64
#  5   Arrivals(Last 24 Hours)    257 non-null    int64
#  6   Expected Arrivals          257 non-null    int64
#  7   Type                       257 non-null    object
#  8   Area Local                 257 non-null    object
#  9   Area Global                257 non-null    object
#  10  Also known as              257 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 24.1+ KB

# %%
port_df.tail(3)

# %%
port_df.info()

# %%
port_df[["Port Name", "Vessels in Port"]].iloc[10:20]

# %%
# if the country name is china and the type is anchorage

# if arrivals are greater than the departures by a 100

# create an array where all null value rows are deleted, and create another array where the null values column is deleted

# if the vessles in port and greater than a 1000 or the depatures are greater than 200

# where expected arrivals are higher than acutal arrivals, print out the middle 10 rows with just 3 columns

# print out the median / mode value for Expected arrivals
