# %%
import matplotlib.pyplot as plt

# %%
# marks = [3,4,4,5,5,8,2,2,1,5,4,8,9,6,7,7]
# Out:
# array([54., 83., 91.,  2., 43., 74., 30., 64.,  3., 93., 73., 96., 98.,
#        22.,  9., 17., 59., 66., 52., 43., 90., 41., 67., 13., 36., 75.,
#        61., 45., 23., 96.,  4., 81., 42., 69., 20.,  6., 53., 36., 99.,
#        73., 17., 98., 25., 10., 52., 31., 72., 96., 60., 74., 46., 67.,
#        67., 83., 97., 37., 71.,  5., 78., 39., 15.,  1., 67., 10., 51.,
#        79., 27., 38., 14., 96., 52., 10., 89., 19., 94., 97.,  1., 45.,
#        75., 51., 34., 82., 59., 56., 88., 34., 98., 76., 78.,  9., 45.,
#        14.,  2., 14.,  7., 73., 79., 42., 32., 26.])

# %%
import numpy as np

marks = (np.random.random(10000)*100).round()
plt.hist(marks, bins=10)
plt.show()

# %%
plt.hist(np.random.normal(size=(10000)), bins=20)
# Out:
# (array([1.000e+00, 3.000e+00, 1.500e+01, 1.900e+01, 7.400e+01, 1.880e+02,
#         3.740e+02, 6.640e+02, 1.121e+03, 1.424e+03, 1.596e+03, 1.513e+03,
#         1.241e+03, 8.710e+02, 4.790e+02, 2.440e+02, 1.110e+02, 4.300e+01,
#         1.400e+01, 5.000e+00]),
#  array([-4.32133731, -3.91652327, -3.51170924, -3.1068952 , -2.70208116,
#         -2.29726713, -1.89245309, -1.48763906, -1.08282502, -0.67801098,
#         -0.27319695,  0.13161709,  0.53643112,  0.94124516,  1.3460592 ,
#          1.75087323,  2.15568727,  2.56050131,  2.96531534,  3.37012938,
#          3.77494341]),
#  <BarContainer object of 20 artists>)
