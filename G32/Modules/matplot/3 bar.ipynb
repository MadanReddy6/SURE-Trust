# %%
import matplotlib.pyplot as plt

# %%
labels = [1,2,3,4]
sizes = [10,20,25,15]

plt.barh(labels, sizes, color = ["red","green"], height=1.2, edgecolor="white")


# create a bar graph to show, total credits earned by different students
# Out:
# <BarContainer object of 4 artists>
