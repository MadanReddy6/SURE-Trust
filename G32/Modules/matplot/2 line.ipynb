# %%
import matplotlib.pyplot as plt
x = [5,5,15,5]
y = [5,15,5,5]

# %%
plt.plot(x,y, c="#03ca3e", linestyle = "-", linewidth=5, marker=".",markersize=50, alpha= 1)
plt.ylim(0,20)
plt.xlim(0,20)

# x[0] += 1
# x[1] += 1
# Out:
# (0.0, 20.0)

# %%
# parlellogram

# isoscales triangle

# First character of your name
